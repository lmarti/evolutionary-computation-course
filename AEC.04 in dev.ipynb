# %%
import numpy
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import axes3d
from scipy.stats import norm, multivariate_normal

# %matplotlib inline

# %%
def generate_normal_sample(mu, sigma, size, plot=False):
    sample = numpy.random.normal(mu, sigma, size)
    
    if plot:
        x = numpy.linspace(mu - 4*sigma, mu + 4*sigma, 100)
        plt.plot(x, norm.pdf(x, mu, sigma), 'r', lw=2)
        plt.hist(sample, 30, normed=True, alpha=0.2)
        plt.annotate('3$\sigma$', 
                     xy=(mu + 3*sigma, 0),  xycoords='data',
                     xytext=(0, 100), textcoords='offset points',
                     fontsize=15,
                     arrowprops=dict(arrowstyle="->",
                                    connectionstyle="arc,angleA=180,armA=20,angleB=90,armB=15,rad=7"))
        plt.annotate('-3$\sigma$', 
                     xy=(mu -3*sigma, 0), xycoords='data', 
                     xytext=(0, 100), textcoords='offset points',
                     fontsize=15,
                     arrowprops=dict(arrowstyle="->",
                                     connectionstyle="arc,angleA=180,armA=20,angleB=90,armB=15,rad=7"))
    return sample

# %%
plt.figure(1, figsize=(11,4))
plt.subplot(121)
sample_1 = generate_normal_sample(0, 0.5, 500, plot=True)
plt.title('Sample 1: $\mu=0$, $\sigma=0.5$')
plt.subplot(122)
sample_2 = generate_normal_sample(1, 1, 500, plot=True)
plt.title('Sample 2: $\mu=1$, $\sigma=1$')
plt.tight_layout()

# %%
print('Sample 1 mean and std. dev.: ', sample_1.mean(), sample_1.std())
print('Sample 2 mean and std. dev.: ', sample_2.mean(), sample_2.std())
# Out:
# ('Sample 1 mean and std. dev.: ', 0.033761733436660064, 0.51354562379603064)
# ('Sample 2 mean and std. dev.: ', 0.9934021415862021, 1.0521513805532174)

# %%
sample = numpy.ndarray(shape=(2,len(sample_1)))

# %%
sample[0] = sample_1
sample[1] = sample_2

# %%
plt.plot(sample[0], sample[1], 'bx')

# %%
numpy.cov(sample)
# Out:
# array([[ 0.26425762, -0.04056104],
#        [-0.04056104,  1.10924101]])

# %%
plt.figure(1, figsize=(5,5))
a = plt.hist2d(sample_1, sample_2, bins= 30, normed=True)

# %%
mu = [0,1]
cov = [[1,0],[0,0.2]] # diagonal covariance, points lie on x or y-axis
sample = numpy.random.multivariate_normal(mu,cov,1000).T
plt.plot(sample[0], sample[1], 'kx', alpha=0.47)

estimated_mean = sample.mean(axis=1)
estimated_cov = numpy.cov(sample)
e_x,e_y = numpy.random.multivariate_normal(estimated_mean,estimated_cov,500).T
plt.plot(e_x,e_y,'rx', alpha=0.47)
x, y = numpy.mgrid[-4:4:.01, -1:3:.01]
pos = numpy.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y
rv = multivariate_normal(estimated_mean, estimated_cov)
plt.contour(x, y, rv.pdf(pos), cmap=cm.coolwarm, lw=4)
plt.axis('equal')
# Out:
# (-4.0, 4.0, -1.0, 3.0)

# %%
fig = plt.figure(figsize=(11,5))
ax = fig.gca(projection='3d')
cset = ax.plot_surface(x, y, rv.pdf(pos), cmap=cm.coolwarm, rstride=30, cstride=10, linewidth=0.25, alpha=0.47)
#ax.clabel(cset, fontsize=9, inline=1)
ax.scatter(e_x, e_y, 0.4, marker='.', alpha=0.47)
ax.axis('tight')
# Out:
# (-4.3994999999999997, 4.3895, -1.1995, 3.1895000000000002)

# %% [markdown]
# What happens if we rotate the sample?

# %%
def rotate_sample(sample, angle=-45):
    'Rotates a sample by `angle` degrees.'
    theta = (angle/180.) * numpy.pi

    rot_matrix = numpy.array([[numpy.cos(theta), -numpy.sin(theta)], 
                         [numpy.sin(theta),  numpy.cos(theta)]])
    return sample.T.dot(rot_matrix).T

# %%
rot_sample = rotate_sample(sample)
estimated_mean = rot_sample.mean(axis=1)
estimated_cov = numpy.cov(rot_sample)
e_x,e_y = numpy.random.multivariate_normal(estimated_mean,estimated_cov,500).T

# %%
fig = plt.figure(figsize=(11,4))
plt.subplot(121)
plt.plot(rot_sample[0], rot_sample[1], 'x', alpha=0.7)
plt.title('"Original" data')
plt.axis('equal')
plt.subplot(122)
plt.plot(e_x,e_y,'rx', alpha=0.7)
plt.title('Sample data')
plt.axis('equal')
# Out:
# (-3.0, 1.5, -1.5, 3.0)

# %%
x, y = numpy.mgrid[-4:4:.01, -3:3:.01]
pos = numpy.empty(x.shape + (2,))
pos[:, :, 0] = x; pos[:, :, 1] = y
rv = multivariate_normal(estimated_mean, estimated_cov)

# %%
fig = plt.figure(figsize=(11,5))
ax = fig.gca(projection='3d')
cset = ax.plot_surface(x, y, rv.pdf(pos), cmap=cm.coolwarm, rstride=40, cstride=10, linewidth=0.15, alpha=0.47)
#ax.clabel(cset, fontsize=9, inline=1)
ax.scatter(e_x, e_y, 0.4, marker='.', alpha=0.47)
ax.axis('tight')
# Out:
# (-4.3994999999999997, 4.3895, -3.2995000000000001, 3.2895000000000003)

# %% [markdown]
# # Evolutionary Strategies

# %%
import array
import random
import time

from deap import base, creator, benchmarks, tools

random.seed(time.time()) # planting a random seed

# %%
def plot_problem_3d(problem, bounds, resolution=100., cmap=cm.coolwarm, rstride=10, cstride=10, linewidth=0.15, alpha=0.65):
    'Plots a given deap benchmark problem'
    (minx,miny),(maxx,maxy) = bounds
    x_range = numpy.arange(minx, maxx, (maxx-minx)/resolution)
    y_range = numpy.arange(miny, maxy, (maxy-miny)/resolution)
    
    X, Y = numpy.meshgrid(x_range, y_range)
    Z = numpy.zeros((len(x_range), len(y_range)))
    
    for i in range(len(x_range)):
        for j in range(len(y_range)):
            Z[i,j] = problem((x_range[i], y_range[j]))[0]
    
    fig = plt.figure(figsize=(11,6))
    ax = fig.gca(projection='3d')
    cset = ax.plot_surface(X, Y, Z, cmap=cmap, rstride=rstride, cstride=cstride, linewidth=linewidth, alpha=alpha)

# %%
def plot_problem_controur(problem, bounds, optimum=None,
                          resolution=100., cmap=cm.coolwarm, 
                          rstride=1, cstride=10, linewidth=0.15, alpha=0.65):
    'Plots a given deap benchmark problem'
    (minx,miny),(maxx,maxy) = bounds
    x_range = numpy.arange(minx, maxx, (maxx-minx)/resolution)
    y_range = numpy.arange(miny, maxy, (maxy-miny)/resolution)
    
    X, Y = numpy.meshgrid(x_range, y_range)
    Z = numpy.zeros((len(x_range), len(y_range)))
    
    for i in range(len(x_range)):
        for j in range(len(y_range)):
            Z[i,j] = problem((x_range[i], y_range[j]))[0]
    
    fig = plt.figure(figsize=(11,6))
    ax = fig.gca()
    cset = ax.contourf(X, Y, Z, cmap=cmap, rstride=rstride, cstride=cstride, linewidth=linewidth, alpha=alpha)
    if optimum:
        ax.plot(optimum[0], optimum[1], 'bx', linewidth=4, markersize=15)

# %% [markdown]
# ### Why benchmarks (test) functions?
#
# In applied mathematics, [test functions](http://en.wikipedia.org/wiki/Test_functions_for_optimization), also known as artificial landscapes, are useful to evaluate characteristics of optimization algorithms, such as:
#
# * Velocity of convergence.
# * Precision.
# * Robustness.
# * General performance.
#
# DEAP has a number of test problems already implemented: http://deap.readthedocs.org/en/latest/api/benchmarks.html

# %% [markdown]
# We will be using the **sphere problem** for these experiments.
#
# $$\text{minimize } f(\mathbf{x}) = \sum_{i=1}^Nx_i^2,\ \mathbf{x}\in\mathbb{R}^n.\text{ Optimum in }\mathbf{x}=\mathbf{0};\ f(\mathbf{0})=0. $$

# %%
plot_problem_3d(benchmarks.bohachevsky, ((-5,-5), (5,5)))

# %%
plot_problem_controur(benchmarks.bohachevsky, ((-5,-5), (5,5)), optimum=(0,0))

# %% [markdown]
# ### ($\mu$,$\lambda$)-ES with uniform $\sigma$

# %%
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", array.array, typecode='d', fitness=creator.FitnessMin, strategy=None)
creator.create("Strategy", array.array, typecode="d")

# %%
def init_univariate_es_ind(individual_class, size, min_value, max_value, min_strategy, max_strategy):
    ind = individual_class(random.uniform(min_value, max_value) for _ in range(size))
    ind.strategy = random.uniform(min_strategy, max_strategy)
    return ind

# %%
search_space_dims = 2 # we want to plot the individuals so this must be 2

toolbox = base.Toolbox() 

MIN_VALUE, MAX_VALUE = -5., 5.
MIN_STRAT, MAX_STRAT = 0., 1. 

toolbox = base.Toolbox()
toolbox.register("individual", init_univariate_es_ind, creator.Individual, search_space_dims, 
                 MIN_VALUE, MAX_VALUE, MIN_STRAT, MAX_STRAT)

# %%
ind = toolbox.individual()

# %%
ind.strategy
# Out:
# 0.060091953292202294

# %%
def mutation(mu):
    cov = np.matlib.eye(len(mu)) * sigma
    return numpy.random.multivariate_normal(mu,cov)

# %%
def plot_cov_ellipse(pos, cov, volume=.5, ax=None, fc='none', ec=[0,0,0], alpha=1, lw=2):
    """
    Plots an ellipse enclosing *volume* based on the specified covariance
    matrix (*cov*) and location (*pos*). Additional keyword arguments are passed on to the 
    ellipse patch artist. 
    
    _Note_: Adapted from http://www.nhsilbert.net/source/2014/06/bivariate-normal-ellipse-plotting-in-python/

    Parameters
    ----------
        cov : The 2x2 covariance matrix to base the ellipse on
        pos : The location of the center of the ellipse. Expects a 2-element
            sequence of [x0, y0].
        volume : The volume inside the ellipse; defaults to 0.5
        ax : The axis that the ellipse will be plotted on. Defaults to the 
            current axis.
    """

    import numpy as np
    from scipy.stats import chi2
    import matplotlib.pyplot as plt
    from matplotlib.patches import Ellipse

    def eigsorted(cov):
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        return vals[order], vecs[:,order]

    if ax is None:
        ax = plt.gca()

    vals, vecs = eigsorted(cov)
    theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))

    kwrg = {'facecolor':fc, 'edgecolor':ec, 'alpha':alpha, 'linewidth':lw}

    # Width and height are "full" widths, not radius
    width, height = 2 * np.sqrt(chi2.ppf(volume,2)) * np.sqrt(vals)
    ellip = Ellipse(xy=pos, width=width, height=height, angle=theta, **kwrg)

    ax.add_artist(ellip)

# %%
numpy.matrix.I

# %%
def plot_individual(individual):
    cov = numpy.eye(len(individual)) * individual.strategy
    plot_cov_ellipse(individual, cov, volume=0.99)
    plt.plot(individual[0], individual[1], 'bx')

# %%
plot_problem_controur(benchmarks.bohachevsky, ((-15,-15), (15,15)), optimum=(0,0))
plot_individual(ind)
plt.axis('equal')
# Out:
# (-15.0, 15.0, -15.0, 15.0)

# %%
                 
toolbox.register("update", mutation)
toolbox.register("evaluate", benchmarks.sphere)
logbook = tools.Logbook()
logbook.header = "gen", "fitness", "individual"

# %%
search_space_dims = 2 # we want to plot individuals

interval = (-3,7)
mu = (random.uniform(interval[0], interval[1]) for _ in range(search_space_dims))
sigma = (interval[1] - interval[0])/2.0
alpha = 2.0**(1.0/search_space_dims)

parent = creator.Individual(mu)
parent.fitness.values = toolbox.evaluate(best)
worst = creator.Individual((0.0,)*IND_SIZE)

# %%
best
# Out:
# array('d', [0.5992183641867381, -2.8241426925905726, -0.6499677974064206, -0.3109429549546445, 5.79682073481375, 6.867691243057484, 3.0229952068798687, -1.6279338099366076, 3.2429929563159616, 5.058191797231283])

# %%
NGEN = 1500
for g in range(NGEN):
    toolbox.update(worst, best, sigma) 
    worst.fitness.values = toolbox.evaluate(worst)
    if best.fitness <= worst.fitness:
        sigma = sigma * alpha
        best, worst = worst, best
    else:
        sigma = sigma * alpha**(-0.25)

# %%
main()
# Out:
# gen	fitness
# 0  	(176.84586144183405,)
# 1  	(176.84586144183405,)
# 2  	(176.84586144183405,)
# 3  	(176.84586144183405,)
# 4  	(176.84586144183405,)
# 5  	(176.84586144183405,)
# 6  	(176.84586144183405,)
# 7  	(176.84586144183405,)
# 8  	(176.84586144183405,)
# 9  	(176.84586144183405,)
# 10 	(176.84586144183405,)
# 11 	(176.84586144183405,)
# 12 	(176.84586144183405,)
# 13 	(176.84586144183405,)
# 14 	(176.84586144183405,)
# 15 	(176.84586144183405,)
# 16 	(176.84586144183405,)
# 17 	(176.84586144183405,)
# 18 	(173.5991570775447,)
# 19 	(173.5991570775447,)
# 20 	(173.5991570775447,)
# 21 	(173.5991570775447,)
# 22 	(173.5991570775447,)
# 23 	(173.5991570775447,)
# 24 	(173.5991570775447,)
# 25 	(173.5991570775447,)
# 26 	(173.5991570775447,)
# 27 	(173.5991570775447,)
# 28 	(173.5991570775447,)
# 29 	(173.5991570775447,)
# 30 	(173.5991570775447,)
# 31 	(173.5991570775447,)
# 32 	(167.40532900654526,)
# 33 	(167.40532900654526,)
# 34 	(167.40532900654526,)
# 35 	(167.40532900654526,)
# 36 	(167.40532900654526,)
# 37 	(165.7478856369081,)
# 38 	(165.7478856369081,)
# 39 	(165.7478856369081,)
# 40 	(165.7478856369081,)
# 41 	(165.7478856369081,)
# 42 	(165.7478856369081,)
# 43 	(165.7478856369081,)
# 44 	(165.7478856369081,)
# 45 	(165.7478856369081,)
# 46 	(114.84268131370979,)
# 47 	(114.84268131370979,)
# 48 	(114.84268131370979,)
# 49 	(114.84268131370979,)
# 50 	(114.84268131370979,)
# 51 	(114.84268131370979,)
# 52 	(114.84268131370979,)
# 53 	(114.84268131370979,)
# 54 	(114.84268131370979,)
# 55 	(114.84268131370979,)
# 56 	(114.84268131370979,)
# 57 	(114.84268131370979,)
# 58 	(86.73142554227067,)
# 59 	(86.73142554227067,)
# 60 	(81.32690654772048,)
# 61 	(70.14055200856632,)
# 62 	(70.14055200856632,)
# 63 	(70.14055200856632,)
# 64 	(70.14055200856632,)
# 65 	(57.421352276433005,)
# 66 	(57.421352276433005,)
# 67 	(57.421352276433005,)
# 68 	(57.421352276433005,)
# 69 	(57.421352276433005,)
# 70 	(57.421352276433005,)
# 71 	(57.421352276433005,)
# 72 	(57.421352276433005,)
# 73 	(57.421352276433005,)
# 74 	(57.421352276433005,)
# 75 	(37.557780270100494,)
# 76 	(37.557780270100494,)
# 77 	(37.557780270100494,)
# 78 	(37.557780270100494,)
# 79 	(37.557780270100494,)
# 80 	(37.557780270100494,)
# 81 	(37.557780270100494,)
# 82 	(37.557780270100494,)
# 83 	(37.557780270100494,)
# 84 	(37.557780270100494,)
# 85 	(37.557780270100494,)
# 86 	(37.557780270100494,)
# 87 	(37.557780270100494,)
# 88 	(37.557780270100494,)
# 89 	(37.557780270100494,)
# 90 	(37.557780270100494,)
# 91 	(37.557780270100494,)
# 92 	(29.158970806272986,)
# 93 	(29.158970806272986,)
# 94 	(29.158970806272986,)
# 95 	(29.158970806272986,)
# 96 	(29.158970806272986,)
# 97 	(29.158970806272986,)
# 98 	(29.158970806272986,)
# 99 	(29.158970806272986,)
# 100	(29.158970806272986,)
# 101	(25.122669040662988,)
# 102	(25.122669040662988,)
# 103	(25.122669040662988,)
# 104	(25.122669040662988,)
# 105	(25.122669040662988,)
# 106	(25.122669040662988,)
# 107	(25.122669040662988,)
# 108	(25.122669040662988,)
# 109	(25.122669040662988,)
# 110	(25.122669040662988,)
# 111	(25.122669040662988,)
# 112	(25.122669040662988,)
# 113	(25.122669040662988,)
# 114	(25.122669040662988,)
# 115	(25.122669040662988,)
# 116	(25.122669040662988,)
# 117	(25.122669040662988,)
# 118	(25.122669040662988,)
# 119	(25.122669040662988,)
# 120	(25.122669040662988,)
# 121	(25.122669040662988,)
# 122	(25.122669040662988,)
# 123	(25.122669040662988,)
# 124	(25.122669040662988,)
# 125	(25.122669040662988,)
# 126	(25.122669040662988,)
# 127	(25.122669040662988,)
# 128	(25.122669040662988,)
# 129	(25.122669040662988,)
# 130	(25.122669040662988,)
# 131	(22.093385885746823,)
# 132	(22.093385885746823,)
# 133	(22.093385885746823,)
# 134	(22.093385885746823,)
# 135	(22.093385885746823,)
# 136	(22.093385885746823,)
# 137	(21.842573559273937,)
# 138	(21.842573559273937,)
# 139	(21.842573559273937,)
# 140	(21.842573559273937,)
# 141	(17.12311566434272,)
# 142	(17.12311566434272,)
# 143	(17.12311566434272,)
# 144	(17.12311566434272,)
# 145	(17.12311566434272,)
# 146	(17.12311566434272,)
# 147	(17.12311566434272,)
# 148	(17.12311566434272,)
# 149	(17.12311566434272,)
# 150	(17.12311566434272,)
# 151	(17.12311566434272,)
# 152	(17.12311566434272,)
# 153	(17.12311566434272,)
# 154	(17.12311566434272,)
# 155	(17.12311566434272,)
# 156	(17.12311566434272,)
# 157	(17.12311566434272,)
# 158	(17.12311566434272,)
# 159	(17.12311566434272,)
# 160	(17.12311566434272,)
# 161	(17.12311566434272,)
# 162	(11.99835280737405,)
# 163	(11.99835280737405,)
# 164	(11.99835280737405,)
# 165	(11.99835280737405,)
# 166	(11.99835280737405,)
# 167	(11.99835280737405,)
# 168	(11.99835280737405,)
# 169	(11.99835280737405,)
# 170	(11.99835280737405,)
# 171	(11.99835280737405,)
# 172	(6.624877870600795,)
# 173	(6.624877870600795,)
# 174	(3.3534685328415454,)
# 175	(3.3534685328415454,)
# 176	(3.3534685328415454,)
# 177	(3.3534685328415454,)
# 178	(3.3534685328415454,)
# 179	(3.3534685328415454,)
# 180	(3.3534685328415454,)
# 181	(3.3534685328415454,)
# 182	(3.3534685328415454,)
# 183	(3.3534685328415454,)
# 184	(3.3534685328415454,)
# 185	(3.3534685328415454,)
# 186	(3.3534685328415454,)
# 187	(3.3534685328415454,)
# 188	(3.3534685328415454,)
# 189	(3.3534685328415454,)
# 190	(3.3534685328415454,)
# 191	(3.2517784265912106,)
# 192	(3.2517784265912106,)
# 193	(3.2517784265912106,)
# 194	(3.2517784265912106,)
# 195	(3.2517784265912106,)
# 196	(3.2517784265912106,)
# 197	(3.2517784265912106,)
# 198	(3.2517784265912106,)
# 199	(3.2517784265912106,)
# 200	(3.2517784265912106,)
# 201	(3.2517784265912106,)
# 202	(3.2517784265912106,)
# 203	(3.2517784265912106,)
# 204	(3.2517784265912106,)
# 205	(3.2517784265912106,)
# 206	(3.2517784265912106,)
# 207	(3.2517784265912106,)
# 208	(3.2517784265912106,)
# 209	(3.2517784265912106,)
# 210	(3.2517784265912106,)
# 211	(3.2517784265912106,)
# 212	(3.2517784265912106,)
# 213	(2.3376006535224176,)
# 214	(2.3376006535224176,)
# 215	(2.3376006535224176,)
# 216	(2.3376006535224176,)
# 217	(2.3376006535224176,)
# 218	(2.3376006535224176,)
# 219	(2.3376006535224176,)
# 220	(2.3376006535224176,)
# 221	(2.3376006535224176,)
# 222	(2.3376006535224176,)
# 223	(2.3376006535224176,)
# 224	(2.3376006535224176,)
# 225	(2.3376006535224176,)
# 226	(2.3376006535224176,)
# 227	(2.3376006535224176,)
# 228	(2.3376006535224176,)
# 229	(2.3376006535224176,)
# 230	(2.3376006535224176,)
# 231	(2.3376006535224176,)
# 232	(2.3376006535224176,)
# 233	(2.3376006535224176,)
# 234	(2.3376006535224176,)
# 235	(2.3376006535224176,)
# 236	(2.3376006535224176,)
# 237	(2.3376006535224176,)
# 238	(2.3376006535224176,)
# 239	(2.3376006535224176,)
# 240	(2.3376006535224176,)
# 241	(2.3376006535224176,)
# 242	(1.6446385612014378,)
# 243	(1.6446385612014378,)
# 244	(1.6446385612014378,)
# 245	(1.6446385612014378,)
# 246	(1.6446385612014378,)
# 247	(1.6446385612014378,)
# 248	(1.6446385612014378,)
# 249	(1.6446385612014378,)
# 250	(1.6446385612014378,)
# 251	(1.6446385612014378,)
# 252	(1.6446385612014378,)
# 253	(1.6446385612014378,)
# 254	(1.6446385612014378,)
# 255	(1.6446385612014378,)
# 256	(1.6446385612014378,)
# 257	(1.6446385612014378,)
# 258	(0.9739142120291759,)
# 259	(0.9739142120291759,)
# 260	(0.9739142120291759,)
# 261	(0.9739142120291759,)
# 262	(0.9739142120291759,)
# 263	(0.9739142120291759,)
# 264	(0.9739142120291759,)
# 265	(0.9739142120291759,)
# 266	(0.9739142120291759,)
# 267	(0.9739142120291759,)
# 268	(0.9739142120291759,)
# 269	(0.9739142120291759,)
# 270	(0.9739142120291759,)
# 271	(0.9739142120291759,)
# 272	(0.9739142120291759,)
# 273	(0.9739142120291759,)
# 274	(0.9739142120291759,)
# 275	(0.9739142120291759,)
# 276	(0.9739142120291759,)
# 277	(0.9739142120291759,)
# 278	(0.9739142120291759,)
# 279	(0.9739142120291759,)
# 280	(0.9739142120291759,)
# 281	(0.9739142120291759,)
# 282	(0.9739142120291759,)
# 283	(0.9739142120291759,)
# 284	(0.9739142120291759,)
# 285	(0.9739142120291759,)
# 286	(0.9739142120291759,)
# 287	(0.4569104462598545,)
# 288	(0.4569104462598545,)
# 289	(0.4569104462598545,)
# 290	(0.4569104462598545,)
# 291	(0.4569104462598545,)
# 292	(0.4569104462598545,)
# 293	(0.4569104462598545,)
# 294	(0.4569104462598545,)
# 295	(0.4569104462598545,)
# 296	(0.4569104462598545,)
# 297	(0.4569104462598545,)
# 298	(0.4569104462598545,)
# 299	(0.4569104462598545,)
# 300	(0.3801246717104508,)
# 301	(0.3801246717104508,)
# 302	(0.3801246717104508,)
# 303	(0.3801246717104508,)
# 304	(0.3801246717104508,)
# 305	(0.3801246717104508,)
# 306	(0.3801246717104508,)
# 307	(0.3801246717104508,)
# 308	(0.3801246717104508,)
# 309	(0.3801246717104508,)
# 310	(0.20837338106327558,)
# 311	(0.20837338106327558,)
# 312	(0.20837338106327558,)
# 313	(0.20837338106327558,)
# 314	(0.20837338106327558,)
# 315	(0.20837338106327558,)
# 316	(0.0996140565289932,)
# 317	(0.0996140565289932,)
# 318	(0.0996140565289932,)
# 319	(0.0996140565289932,)
# 320	(0.0996140565289932,)
# 321	(0.0996140565289932,)
# 322	(0.0996140565289932,)
# 323	(0.0996140565289932,)
# 324	(0.0996140565289932,)
# 325	(0.0996140565289932,)
# 326	(0.0996140565289932,)
# 327	(0.0996140565289932,)
# 328	(0.0996140565289932,)
# 329	(0.0996140565289932,)
# 330	(0.0996140565289932,)
# 331	(0.0996140565289932,)
# 332	(0.0996140565289932,)
# 333	(0.0996140565289932,)
# 334	(0.0996140565289932,)
# 335	(0.0996140565289932,)
# 336	(0.0996140565289932,)
# 337	(0.0996140565289932,)
# 338	(0.0996140565289932,)
# 339	(0.0996140565289932,)
# 340	(0.0996140565289932,)
# 341	(0.0996140565289932,)
# 342	(0.0996140565289932,)
# 343	(0.0996140565289932,)
# 344	(0.0996140565289932,)
# 345	(0.0996140565289932,)
# 346	(0.0996140565289932,)
# 347	(0.0996140565289932,)
# 348	(0.0996140565289932,)
# 349	(0.0996140565289932,)
# 350	(0.0996140565289932,)
# 351	(0.0996140565289932,)
# 352	(0.0996140565289932,)
# 353	(0.0996140565289932,)
# 354	(0.0996140565289932,)
# 355	(0.0996140565289932,)
# 356	(0.0996140565289932,)
# 357	(0.0996140565289932,)
# 358	(0.0996140565289932,)
# 359	(0.0996140565289932,)
# 360	(0.0996140565289932,)
# 361	(0.0996140565289932,)
# 362	(0.0996140565289932,)
# 363	(0.0996140565289932,)
# 364	(0.0996140565289932,)
# 365	(0.0996140565289932,)
# 366	(0.0996140565289932,)
# 367	(0.0996140565289932,)
# 368	(0.0996140565289932,)
# 369	(0.0996140565289932,)
# 370	(0.0996140565289932,)
# 371	(0.0996140565289932,)
# 372	(0.0996140565289932,)
# 373	(0.0996140565289932,)
# 374	(0.0996140565289932,)
# 375	(0.0996140565289932,)
# 376	(0.0996140565289932,)
# 377	(0.0996140565289932,)
# 378	(0.0996140565289932,)
# 379	(0.0996140565289932,)
# 380	(0.0996140565289932,)
# 381	(0.0996140565289932,)
# 382	(0.0996140565289932,)
# 383	(0.0996140565289932,)
# 384	(0.0996140565289932,)
# 385	(0.0996140565289932,)
# 386	(0.0996140565289932,)
# 387	(0.0996140565289932,)
# 388	(0.0996140565289932,)
# 389	(0.0996140565289932,)
# 390	(0.0996140565289932,)
# 391	(0.0996140565289932,)
# 392	(0.0996140565289932,)
# 393	(0.0996140565289932,)
# 394	(0.0996140565289932,)
# 395	(0.0996140565289932,)
# 396	(0.0996140565289932,)
# 397	(0.0996140565289932,)
# 398	(0.0996140565289932,)
# 399	(0.0996140565289932,)
# 400	(0.09247216711262242,)
# 401	(0.08411267235784906,)
# 402	(0.08411267235784906,)
# 403	(0.08411267235784906,)
# 404	(0.08411267235784906,)
# 405	(0.08411267235784906,)
# 406	(0.08411267235784906,)
# 407	(0.08411267235784906,)
# 408	(0.08339506429139759,)
# 409	(0.08339506429139759,)
# 410	(0.05515585372252392,)
# 411	(0.04974869979453341,)
# 412	(0.04974869979453341,)
# 413	(0.028180594402979077,)
# 414	(0.028180594402979077,)
# 415	(0.028180594402979077,)
# 416	(0.028180594402979077,)
# 417	(0.028180594402979077,)
# 418	(0.028180594402979077,)
# 419	(0.028180594402979077,)
# 420	(0.028180594402979077,)
# 421	(0.028180594402979077,)
# 422	(0.028180594402979077,)
# 423	(0.028180594402979077,)
# 424	(0.028180594402979077,)
# 425	(0.028180594402979077,)
# 426	(0.028180594402979077,)
# 427	(0.028180594402979077,)
# 428	(0.028180594402979077,)
# 429	(0.028180594402979077,)
# 430	(0.02754028181627108,)
# 431	(0.02754028181627108,)
# 432	(0.02754028181627108,)
# 433	(0.02754028181627108,)
# 434	(0.02754028181627108,)
# 435	(0.02754028181627108,)
# 436	(0.02754028181627108,)
# 437	(0.02754028181627108,)
# 438	(0.02754028181627108,)
# 439	(0.02754028181627108,)
# 440	(0.02128943575012061,)
# 441	(0.019323729573607736,)
# 442	(0.019323729573607736,)
# 443	(0.019323729573607736,)
# 444	(0.019323729573607736,)
# 445	(0.018461089527590614,)
# 446	(0.018461089527590614,)
# 447	(0.018461089527590614,)
# 448	(0.018461089527590614,)
# 449	(0.018461089527590614,)
# 450	(0.018461089527590614,)
# 451	(0.018461089527590614,)
# 452	(0.018461089527590614,)
# 453	(0.018461089527590614,)
# 454	(0.018212589289583022,)
# 455	(0.018212589289583022,)
# 456	(0.018212589289583022,)
# 457	(0.018212589289583022,)
# 458	(0.018212589289583022,)
# 459	(0.018212589289583022,)
# 460	(0.018212589289583022,)
# 461	(0.013017181398019887,)
# 462	(0.013017181398019887,)
# 463	(0.013017181398019887,)
# 464	(0.013017181398019887,)
# 465	(0.013017181398019887,)
# 466	(0.013017181398019887,)
# 467	(0.013017181398019887,)
# 468	(0.012137652861416397,)
# 469	(0.012137652861416397,)
# 470	(0.012137652861416397,)
# 471	(0.010434902841153715,)
# 472	(0.010434902841153715,)
# 473	(0.008471091673132217,)
# 474	(0.008471091673132217,)
# 475	(0.008471091673132217,)
# 476	(0.008471091673132217,)
# 477	(0.008471091673132217,)
# 478	(0.008471091673132217,)
# 479	(0.008471091673132217,)
# 480	(0.008471091673132217,)
# 481	(0.008471091673132217,)
# 482	(0.008471091673132217,)
# 483	(0.008471091673132217,)
# 484	(0.008471091673132217,)
# 485	(0.008471091673132217,)
# 486	(0.008471091673132217,)
# 487	(0.008471091673132217,)
# 488	(0.008471091673132217,)
# 489	(0.008471091673132217,)
# 490	(0.008471091673132217,)
# 491	(0.008471091673132217,)
# 492	(0.008471091673132217,)
# 493	(0.008471091673132217,)
# 494	(0.008471091673132217,)
# 495	(0.008471091673132217,)
# 496	(0.008471091673132217,)
# 497	(0.008471091673132217,)
# 498	(0.008471091673132217,)
# 499	(0.006843793568988385,)
# 500	(0.006843793568988385,)
# 501	(0.006843793568988385,)
# 502	(0.005405690383968812,)
# 503	(0.005405690383968812,)
# 504	(0.005405690383968812,)
# 505	(0.005405690383968812,)
# 506	(0.005405690383968812,)
# 507	(0.005405690383968812,)
# 508	(0.005405690383968812,)
# 509	(0.005405690383968812,)
# 510	(0.005405690383968812,)
# 511	(0.005405690383968812,)
# 512	(0.005405690383968812,)
# 513	(0.005405690383968812,)
# 514	(0.005405690383968812,)
# 515	(0.005405690383968812,)
# 516	(0.005405690383968812,)
# 517	(0.005405690383968812,)
# 518	(0.005405690383968812,)
# 519	(0.005405690383968812,)
# 520	(0.005405690383968812,)
# 521	(0.005405690383968812,)
# 522	(0.005405690383968812,)
# 523	(0.004616873818914236,)
# 524	(0.004616873818914236,)
# 525	(0.004616873818914236,)
# 526	(0.004616873818914236,)
# 527	(0.004616873818914236,)
# 528	(0.004616873818914236,)
# 529	(0.004616873818914236,)
# 530	(0.004616873818914236,)
# 531	(0.004616873818914236,)
# 532	(0.004616873818914236,)
# 533	(0.004616873818914236,)
# 534	(0.004616873818914236,)
# 535	(0.004616873818914236,)
# 536	(0.004616873818914236,)
# 537	(0.004616873818914236,)
# 538	(0.004616873818914236,)
# 539	(0.004616873818914236,)
# 540	(0.004616873818914236,)
# 541	(0.004616873818914236,)
# 542	(0.004616873818914236,)
# 543	(0.004616873818914236,)
# 544	(0.004616873818914236,)
# 545	(0.003119042609814977,)
# 546	(0.003119042609814977,)
# 547	(0.003119042609814977,)
# 548	(0.003119042609814977,)
# 549	(0.003119042609814977,)
# 550	(0.003119042609814977,)
# 551	(0.003119042609814977,)
# 552	(0.003119042609814977,)
# 553	(0.0016681209886876846,)
# 554	(0.0016681209886876846,)
# 555	(0.0016681209886876846,)
# 556	(0.0016681209886876846,)
# 557	(0.0016681209886876846,)
# 558	(0.0016681209886876846,)
# 559	(0.0016681209886876846,)
# 560	(0.0016681209886876846,)
# 561	(0.0016681209886876846,)
# 562	(0.0016681209886876846,)
# 563	(0.0016681209886876846,)
# 564	(0.0016681209886876846,)
# 565	(0.0016681209886876846,)
# 566	(0.0016681209886876846,)
# 567	(0.0016681209886876846,)
# 568	(0.0016681209886876846,)
# 569	(0.0016681209886876846,)
# 570	(0.0016681209886876846,)
# 571	(0.0016681209886876846,)
# 572	(0.0016681209886876846,)
# 573	(0.0016681209886876846,)
# 574	(0.0016681209886876846,)
# 575	(0.0016681209886876846,)
# 576	(0.0016681209886876846,)
# 577	(0.0016681209886876846,)
# 578	(0.0016510902349586164,)
# 579	(0.0016510902349586164,)
# 580	(0.0016510902349586164,)
# 581	(0.0016510902349586164,)
# 582	(0.0016510902349586164,)
# 583	(0.0016510902349586164,)
# 584	(0.0016441623892806396,)
# 585	(0.0016441623892806396,)
# 586	(0.0016259906333246396,)
# 587	(0.0016259906333246396,)
# 588	(0.0016259906333246396,)
# 589	(0.0016259906333246396,)
# 590	(0.0016259906333246396,)
# 591	(0.0015661407438166128,)
# 592	(0.0015661407438166128,)
# 593	(0.0015661407438166128,)
# 594	(0.0015661407438166128,)
# 595	(0.0015661407438166128,)
# 596	(0.0015661407438166128,)
# 597	(0.0015661407438166128,)
# 598	(0.001306073283705937,)
# 599	(0.001306073283705937,)
# 600	(0.001306073283705937,)
# 601	(0.001306073283705937,)
# 602	(0.001306073283705937,)
# 603	(0.001306073283705937,)
# 604	(0.001306073283705937,)
# 605	(0.001306073283705937,)
# 606	(0.001306073283705937,)
# 607	(0.001306073283705937,)
# 608	(0.001306073283705937,)
# 609	(0.0012368068981211224,)
# 610	(0.0012368068981211224,)
# 611	(0.0012368068981211224,)
# 612	(0.0012368068981211224,)
# 613	(0.0012368068981211224,)
# 614	(0.0012368068981211224,)
# 615	(0.0012368068981211224,)
# 616	(0.0012368068981211224,)
# 617	(0.0012368068981211224,)
# 618	(0.0012368068981211224,)
# 619	(0.0012368068981211224,)
# 620	(0.0012368068981211224,)
# 621	(0.0007227627191882231,)
# 622	(0.0007227627191882231,)
# 623	(0.0007227627191882231,)
# 624	(0.0007227627191882231,)
# 625	(0.0007227627191882231,)
# 626	(0.0007227627191882231,)
# 627	(0.0007227627191882231,)
# 628	(0.0007227627191882231,)
# 629	(0.0007227627191882231,)
# 630	(0.0007227627191882231,)
# 631	(0.0007227627191882231,)
# 632	(0.0007227627191882231,)
# 633	(0.0007227627191882231,)
# 634	(0.0005016554752233951,)
# 635	(0.0005016554752233951,)
# 636	(0.0005016554752233951,)
# 637	(0.0005016554752233951,)
# 638	(0.0005016554752233951,)
# 639	(0.0005016554752233951,)
# 640	(0.0005016554752233951,)
# 641	(0.0005016554752233951,)
# 642	(0.0005016554752233951,)
# 643	(0.0005016554752233951,)
# 644	(0.0005016554752233951,)
# 645	(0.0005016554752233951,)
# 646	(0.0005016554752233951,)
# 647	(0.0005016554752233951,)
# 648	(0.0005016554752233951,)
# 649	(0.0005016554752233951,)
# 650	(0.0005016554752233951,)
# 651	(0.0005016554752233951,)
# 652	(0.0003789415492451541,)
# 653	(0.0003789415492451541,)
# 654	(0.0003789415492451541,)
# 655	(0.0003789415492451541,)
# 656	(0.0003789415492451541,)
# 657	(0.0003789415492451541,)
# 658	(0.0003789415492451541,)
# 659	(0.0003789415492451541,)
# 660	(0.0003789415492451541,)
# 661	(0.0003789415492451541,)
# 662	(0.0003789415492451541,)
# 663	(0.0003789415492451541,)
# 664	(0.0003789415492451541,)
# 665	(0.0003789415492451541,)
# 666	(0.0003789415492451541,)
# 667	(0.0003789415492451541,)
# 668	(0.0003789415492451541,)
# 669	(0.0003789415492451541,)
# 670	(0.0003789415492451541,)
# 671	(0.0003789415492451541,)
# 672	(0.0003035388869305763,)
# 673	(0.0003035388869305763,)
# 674	(0.0003035388869305763,)
# 675	(0.0003035388869305763,)
# 676	(0.0003035388869305763,)
# 677	(0.00026521842363239545,)
# 678	(0.00026521842363239545,)
# 679	(0.00026521842363239545,)
# 680	(0.00026521842363239545,)
# 681	(0.00026521842363239545,)
# 682	(0.00026521842363239545,)
# 683	(0.00026521842363239545,)
# 684	(0.00026521842363239545,)
# 685	(0.00026521842363239545,)
# 686	(0.00026521842363239545,)
# 687	(0.00026521842363239545,)
# 688	(0.00024192308101363607,)
# 689	(0.00024192308101363607,)
# 690	(0.00024192308101363607,)
# 691	(0.00018826142715650792,)
# 692	(0.00018826142715650792,)
# 693	(0.00018826142715650792,)
# 694	(0.00018826142715650792,)
# 695	(0.00018826142715650792,)
# 696	(0.00018826142715650792,)
# 697	(0.00018826142715650792,)
# 698	(0.00018826142715650792,)
# 699	(0.00018826142715650792,)
# 700	(0.00018826142715650792,)
# 701	(0.00018826142715650792,)
# 702	(0.00011969584527281661,)
# 703	(0.00011969584527281661,)
# 704	(0.00011969584527281661,)
# 705	(0.00011969584527281661,)
# 706	(0.00011969584527281661,)
# 707	(0.00011969584527281661,)
# 708	(0.00010842208820168426,)
# 709	(0.00010842208820168426,)
# 710	(0.00010842208820168426,)
# 711	(0.00010842208820168426,)
# 712	(0.00010842208820168426,)
# 713	(0.00010842208820168426,)
# 714	(0.00010842208820168426,)
# 715	(0.00010842208820168426,)
# 716	(0.00010842208820168426,)
# 717	(0.00010842208820168426,)
# 718	(0.00010842208820168426,)
# 719	(0.00010842208820168426,)
# 720	(0.00010842208820168426,)
# 721	(0.00010842208820168426,)
# 722	(0.00010842208820168426,)
# 723	(0.00010842208820168426,)
# 724	(0.00010842208820168426,)
# 725	(0.00010842208820168426,)
# 726	(0.00010842208820168426,)
# 727	(0.00010842208820168426,)
# 728	(0.00010842208820168426,)
# 729	(0.00010842208820168426,)
# 730	(0.00010842208820168426,)
# 731	(8.728343842202637e-05,)
# 732	(8.728343842202637e-05,)
# 733	(8.728343842202637e-05,)
# 734	(8.728343842202637e-05,)
# 735	(8.728343842202637e-05,)
# 736	(8.728343842202637e-05,)
# 737	(8.728343842202637e-05,)
# 738	(8.728343842202637e-05,)
# 739	(8.728343842202637e-05,)
# 740	(8.728343842202637e-05,)
# 741	(8.728343842202637e-05,)
# 742	(8.728343842202637e-05,)
# 743	(7.519246565726601e-05,)
# 744	(7.519246565726601e-05,)
# 745	(7.519246565726601e-05,)
# 746	(7.519246565726601e-05,)
# 747	(7.519246565726601e-05,)
# 748	(7.519246565726601e-05,)
# 749	(7.519246565726601e-05,)
# 750	(7.519246565726601e-05,)
# 751	(7.519246565726601e-05,)
# 752	(7.519246565726601e-05,)
# 753	(7.519246565726601e-05,)
# 754	(7.519246565726601e-05,)
# 755	(7.519246565726601e-05,)
# 756	(7.519246565726601e-05,)
# 757	(4.317069189065941e-05,)
# 758	(3.7048368398474393e-05,)
# 759	(3.7048368398474393e-05,)
# 760	(3.7048368398474393e-05,)
# 761	(3.7048368398474393e-05,)
# 762	(3.7048368398474393e-05,)
# 763	(3.7048368398474393e-05,)
# 764	(3.7048368398474393e-05,)
# 765	(3.7048368398474393e-05,)
# 766	(3.7048368398474393e-05,)
# 767	(3.7048368398474393e-05,)
# 768	(3.7048368398474393e-05,)
# 769	(3.7048368398474393e-05,)
# 770	(3.7048368398474393e-05,)
# 771	(3.7048368398474393e-05,)
# 772	(3.7048368398474393e-05,)
# 773	(3.7048368398474393e-05,)
# 774	(3.7048368398474393e-05,)
# 775	(3.7048368398474393e-05,)
# 776	(3.7048368398474393e-05,)
# 777	(3.7048368398474393e-05,)
# 778	(3.7048368398474393e-05,)
# 779	(3.7048368398474393e-05,)
# 780	(3.7048368398474393e-05,)
# 781	(3.7048368398474393e-05,)
# 782	(3.7048368398474393e-05,)
# 783	(3.7048368398474393e-05,)
# 784	(3.7048368398474393e-05,)
# 785	(3.7048368398474393e-05,)
# 786	(3.7048368398474393e-05,)
# 787	(3.7048368398474393e-05,)
# 788	(3.7048368398474393e-05,)
# 789	(3.7048368398474393e-05,)
# 790	(2.2143475967136433e-05,)
# 791	(2.2143475967136433e-05,)
# 792	(2.2143475967136433e-05,)
# 793	(2.2143475967136433e-05,)
# 794	(2.2143475967136433e-05,)
# 795	(2.2143475967136433e-05,)
# 796	(2.2143475967136433e-05,)
# 797	(2.2143475967136433e-05,)
# 798	(2.2143475967136433e-05,)
# 799	(2.2143475967136433e-05,)
# 800	(2.2143475967136433e-05,)
# 801	(2.2143475967136433e-05,)
# 802	(2.2143475967136433e-05,)
# 803	(2.2143475967136433e-05,)
# 804	(2.2143475967136433e-05,)
# 805	(2.2143475967136433e-05,)
# 806	(2.2143475967136433e-05,)
# 807	(2.2143475967136433e-05,)
# 808	(2.2143475967136433e-05,)
# 809	(2.2143475967136433e-05,)
# 810	(2.2143475967136433e-05,)
# 811	(2.2143475967136433e-05,)
# 812	(2.2143475967136433e-05,)
# 813	(2.2143475967136433e-05,)
# 814	(1.4864649010870071e-05,)
# 815	(1.4864649010870071e-05,)
# 816	(1.4864649010870071e-05,)
# 817	(1.4864649010870071e-05,)
# 818	(1.4864649010870071e-05,)
# 819	(1.4864649010870071e-05,)
# 820	(1.3794207636596848e-05,)
# 821	(1.3794207636596848e-05,)
# 822	(1.3794207636596848e-05,)
# 823	(1.3794207636596848e-05,)
# 824	(1.1430768631266843e-05,)
# 825	(1.1430768631266843e-05,)
# 826	(1.1430768631266843e-05,)
# 827	(1.1430768631266843e-05,)
# 828	(1.1430768631266843e-05,)
# 829	(1.1430768631266843e-05,)
# 830	(1.1430768631266843e-05,)
# 831	(1.1430768631266843e-05,)
# 832	(1.1430768631266843e-05,)
# 833	(1.1430768631266843e-05,)
# 834	(1.1430768631266843e-05,)
# 835	(1.1430768631266843e-05,)
# 836	(9.310694055169112e-06,)
# 837	(9.310694055169112e-06,)
# 838	(9.310694055169112e-06,)
# 839	(9.310694055169112e-06,)
# 840	(9.310694055169112e-06,)
# 841	(9.310694055169112e-06,)
# 842	(9.310694055169112e-06,)
# 843	(9.310694055169112e-06,)
# 844	(9.310694055169112e-06,)
# 845	(9.310694055169112e-06,)
# 846	(9.310694055169112e-06,)
# 847	(9.310694055169112e-06,)
# 848	(9.310694055169112e-06,)
# 849	(9.310694055169112e-06,)
# 850	(9.310694055169112e-06,)
# 851	(9.310694055169112e-06,)
# 852	(9.310694055169112e-06,)
# 853	(9.310694055169112e-06,)
# 854	(9.310694055169112e-06,)
# 855	(9.310694055169112e-06,)
# 856	(9.310694055169112e-06,)
# 857	(9.310694055169112e-06,)
# 858	(9.310694055169112e-06,)
# 859	(9.310694055169112e-06,)
# 860	(9.310694055169112e-06,)
# 861	(9.310694055169112e-06,)
# 862	(9.310694055169112e-06,)
# 863	(9.310694055169112e-06,)
# 864	(9.310694055169112e-06,)
# 865	(9.310694055169112e-06,)
# 866	(9.310694055169112e-06,)
# 867	(9.310694055169112e-06,)
# 868	(9.310694055169112e-06,)
# 869	(9.223152633251495e-06,)
# 870	(9.223152633251495e-06,)
# 871	(9.223152633251495e-06,)
# 872	(9.223152633251495e-06,)
# 873	(9.223152633251495e-06,)
# 874	(9.223152633251495e-06,)
# 875	(9.223152633251495e-06,)
# 876	(9.074439231902536e-06,)
# 877	(9.074439231902536e-06,)
# 878	(7.859689291035803e-06,)
# 879	(7.859689291035803e-06,)
# 880	(7.859689291035803e-06,)
# 881	(7.859689291035803e-06,)
# 882	(7.859689291035803e-06,)
# 883	(7.859689291035803e-06,)
# 884	(7.859689291035803e-06,)
# 885	(7.859689291035803e-06,)
# 886	(7.859689291035803e-06,)
# 887	(7.859689291035803e-06,)
# 888	(7.859689291035803e-06,)
# 889	(7.859689291035803e-06,)
# 890	(7.859689291035803e-06,)
# 891	(7.859689291035803e-06,)
# 892	(7.859689291035803e-06,)
# 893	(7.859689291035803e-06,)
# 894	(7.859689291035803e-06,)
# 895	(7.579519425539587e-06,)
# 896	(6.940834929706912e-06,)
# 897	(6.940834929706912e-06,)
# 898	(6.940834929706912e-06,)
# 899	(6.940834929706912e-06,)
# 900	(6.940834929706912e-06,)
# 901	(6.940834929706912e-06,)
# 902	(4.466484488509439e-06,)
# 903	(4.466484488509439e-06,)
# 904	(4.466484488509439e-06,)
# 905	(4.466484488509439e-06,)
# 906	(4.466484488509439e-06,)
# 907	(4.466484488509439e-06,)
# 908	(4.466484488509439e-06,)
# 909	(4.466484488509439e-06,)
# 910	(4.466484488509439e-06,)
# 911	(3.979966157940724e-06,)
# 912	(3.979966157940724e-06,)
# 913	(3.979966157940724e-06,)
# 914	(3.979966157940724e-06,)
# 915	(3.979966157940724e-06,)
# 916	(3.979966157940724e-06,)
# 917	(3.979966157940724e-06,)
# 918	(3.979966157940724e-06,)
# 919	(3.979966157940724e-06,)
# 920	(3.979966157940724e-06,)
# 921	(2.478289147826171e-06,)
# 922	(2.478289147826171e-06,)
# 923	(2.478289147826171e-06,)
# 924	(2.478289147826171e-06,)
# 925	(2.478289147826171e-06,)
# 926	(2.126532626797582e-06,)
# 927	(2.126532626797582e-06,)
# 928	(2.126532626797582e-06,)
# 929	(2.126532626797582e-06,)
# 930	(2.126532626797582e-06,)
# 931	(2.126532626797582e-06,)
# 932	(2.126532626797582e-06,)
# 933	(2.126532626797582e-06,)
# 934	(2.126532626797582e-06,)
# 935	(2.126532626797582e-06,)
# 936	(1.6781996557396321e-06,)
# 937	(1.6781996557396321e-06,)
# 938	(1.6781996557396321e-06,)
# 939	(1.6781996557396321e-06,)
# 940	(1.6781996557396321e-06,)
# 941	(1.6781996557396321e-06,)
# 942	(1.6781996557396321e-06,)
# 943	(1.6781996557396321e-06,)
# 944	(1.6781996557396321e-06,)
# 945	(1.6781996557396321e-06,)
# 946	(1.6781996557396321e-06,)
# 947	(1.6781996557396321e-06,)
# 948	(1.6781996557396321e-06,)
# 949	(1.6781996557396321e-06,)
# 950	(1.6781996557396321e-06,)
# 951	(1.6781996557396321e-06,)
# 952	(1.6781996557396321e-06,)
# 953	(1.502891976972771e-06,)
# 954	(1.502891976972771e-06,)
# 955	(1.502891976972771e-06,)
# 956	(1.502891976972771e-06,)
# 957	(1.502891976972771e-06,)
# 958	(1.502891976972771e-06,)
# 959	(1.502891976972771e-06,)
# 960	(1.502891976972771e-06,)
# 961	(1.502891976972771e-06,)
# 962	(1.502891976972771e-06,)
# 963	(1.0535273939519874e-06,)
# 964	(1.0535273939519874e-06,)
# 965	(1.0535273939519874e-06,)
# 966	(1.0535273939519874e-06,)
# 967	(1.0535273939519874e-06,)
# 968	(1.0535273939519874e-06,)
# 969	(1.0535273939519874e-06,)
# 970	(1.0535273939519874e-06,)
# 971	(1.0535273939519874e-06,)
# 972	(1.0535273939519874e-06,)
# 973	(1.0222335340687234e-06,)
# 974	(1.0222335340687234e-06,)
# 975	(1.0222335340687234e-06,)
# 976	(1.0222335340687234e-06,)
# 977	(1.0222335340687234e-06,)
# 978	(1.0222335340687234e-06,)
# 979	(1.0222335340687234e-06,)
# 980	(1.0222335340687234e-06,)
# 981	(1.0222335340687234e-06,)
# 982	(1.0222335340687234e-06,)
# 983	(1.0222335340687234e-06,)
# 984	(1.0222335340687234e-06,)
# 985	(8.689887348871394e-07,)
# 986	(8.689887348871394e-07,)
# 987	(8.689887348871394e-07,)
# 988	(8.689887348871394e-07,)
# 989	(8.689887348871394e-07,)
# 990	(8.689887348871394e-07,)
# 991	(8.689887348871394e-07,)
# 992	(8.689887348871394e-07,)
# 993	(8.689887348871394e-07,)
# 994	(8.689887348871394e-07,)
# 995	(8.689887348871394e-07,)
# 996	(8.689887348871394e-07,)
# 997	(8.689887348871394e-07,)
# 998	(8.689887348871394e-07,)
# 999	(8.689887348871394e-07,)
# 1000	(5.927661983464113e-07,)
# 1001	(5.927661983464113e-07,)
# 1002	(5.927661983464113e-07,)
# 1003	(5.927661983464113e-07,)
# 1004	(5.927661983464113e-07,)
# 1005	(5.927661983464113e-07,)
# 1006	(5.927661983464113e-07,)
# 1007	(5.927661983464113e-07,)
# 1008	(5.927661983464113e-07,)
# 1009	(5.927661983464113e-07,)
# 1010	(5.927661983464113e-07,)
# 1011	(4.4863870480557236e-07,)
# 1012	(4.4863870480557236e-07,)
# 1013	(4.4863870480557236e-07,)
# 1014	(4.4863870480557236e-07,)
# 1015	(4.4863870480557236e-07,)
# 1016	(4.4863870480557236e-07,)
# 1017	(4.4863870480557236e-07,)
# 1018	(4.4863870480557236e-07,)
# 1019	(4.4863870480557236e-07,)
# 1020	(4.4863870480557236e-07,)
# 1021	(4.4863870480557236e-07,)
# 1022	(2.937783687568577e-07,)
# 1023	(2.937783687568577e-07,)
# 1024	(2.937783687568577e-07,)
# 1025	(2.937783687568577e-07,)
# 1026	(2.937783687568577e-07,)
# 1027	(2.862726421754053e-07,)
# 1028	(2.862726421754053e-07,)
# 1029	(2.862726421754053e-07,)
# 1030	(2.862726421754053e-07,)
# 1031	(2.862726421754053e-07,)
# 1032	(2.862726421754053e-07,)
# 1033	(2.862726421754053e-07,)
# 1034	(2.862726421754053e-07,)
# 1035	(2.862726421754053e-07,)
# 1036	(2.862726421754053e-07,)
# 1037	(2.862726421754053e-07,)
# 1038	(2.862726421754053e-07,)
# 1039	(2.862726421754053e-07,)
# 1040	(2.862726421754053e-07,)
# 1041	(2.862726421754053e-07,)
# 1042	(2.862726421754053e-07,)
# 1043	(2.862726421754053e-07,)
# 1044	(2.727353506064306e-07,)
# 1045	(2.727353506064306e-07,)
# 1046	(2.727353506064306e-07,)
# 1047	(2.727353506064306e-07,)
# 1048	(2.727353506064306e-07,)
# 1049	(2.727353506064306e-07,)
# 1050	(2.727353506064306e-07,)
# 1051	(2.727353506064306e-07,)
# 1052	(2.727353506064306e-07,)
# 1053	(2.727353506064306e-07,)
# 1054	(2.727353506064306e-07,)
# 1055	(2.727353506064306e-07,)
# 1056	(2.727353506064306e-07,)
# 1057	(2.0962323870090458e-07,)
# 1058	(2.0962323870090458e-07,)
# 1059	(2.0962323870090458e-07,)
# 1060	(2.0962323870090458e-07,)
# 1061	(2.0962323870090458e-07,)
# 1062	(2.0962323870090458e-07,)
# 1063	(2.0962323870090458e-07,)
# 1064	(2.0962323870090458e-07,)
# 1065	(2.0962323870090458e-07,)
# 1066	(2.0962323870090458e-07,)
# 1067	(2.0962323870090458e-07,)
# 1068	(2.0962323870090458e-07,)
# 1069	(2.0962323870090458e-07,)
# 1070	(1.7701097681087035e-07,)
# 1071	(1.7701097681087035e-07,)
# 1072	(1.7701097681087035e-07,)
# 1073	(1.7701097681087035e-07,)
# 1074	(1.3620545967764107e-07,)
# 1075	(1.3620545967764107e-07,)
# 1076	(1.3620545967764107e-07,)
# 1077	(1.3620545967764107e-07,)
# 1078	(1.3620545967764107e-07,)
# 1079	(1.3620545967764107e-07,)
# 1080	(1.3620545967764107e-07,)
# 1081	(1.3620545967764107e-07,)
# 1082	(1.3620545967764107e-07,)
# 1083	(1.3620545967764107e-07,)
# 1084	(1.3620545967764107e-07,)
# 1085	(8.603246570108248e-08,)
# 1086	(8.603246570108248e-08,)
# 1087	(8.603246570108248e-08,)
# 1088	(8.603246570108248e-08,)
# 1089	(8.603246570108248e-08,)
# 1090	(8.603246570108248e-08,)
# 1091	(6.752121543372309e-08,)
# 1092	(6.752121543372309e-08,)
# 1093	(6.752121543372309e-08,)
# 1094	(6.752121543372309e-08,)
# 1095	(6.752121543372309e-08,)
# 1096	(6.752121543372309e-08,)
# 1097	(6.752121543372309e-08,)
# 1098	(6.752121543372309e-08,)
# 1099	(6.752121543372309e-08,)
# 1100	(6.752121543372309e-08,)
# 1101	(6.752121543372309e-08,)
# 1102	(6.752121543372309e-08,)
# 1103	(6.752121543372309e-08,)
# 1104	(6.752121543372309e-08,)
# 1105	(6.752121543372309e-08,)
# 1106	(5.770123015764042e-08,)
# 1107	(5.770123015764042e-08,)
# 1108	(5.770123015764042e-08,)
# 1109	(5.770123015764042e-08,)
# 1110	(5.770123015764042e-08,)
# 1111	(4.1208272671414623e-08,)
# 1112	(4.1208272671414623e-08,)
# 1113	(4.1208272671414623e-08,)
# 1114	(4.1208272671414623e-08,)
# 1115	(4.1208272671414623e-08,)
# 1116	(4.1208272671414623e-08,)
# 1117	(4.1208272671414623e-08,)
# 1118	(4.1208272671414623e-08,)
# 1119	(4.1208272671414623e-08,)
# 1120	(4.1208272671414623e-08,)
# 1121	(4.1208272671414623e-08,)
# 1122	(4.1208272671414623e-08,)
# 1123	(4.1208272671414623e-08,)
# 1124	(4.1208272671414623e-08,)
# 1125	(4.1208272671414623e-08,)
# 1126	(4.1208272671414623e-08,)
# 1127	(4.1208272671414623e-08,)
# 1128	(4.1208272671414623e-08,)
# 1129	(4.1208272671414623e-08,)
# 1130	(4.1208272671414623e-08,)
# 1131	(3.346689151484388e-08,)
# 1132	(3.346689151484388e-08,)
# 1133	(3.346689151484388e-08,)
# 1134	(3.346689151484388e-08,)
# 1135	(3.346689151484388e-08,)
# 1136	(3.346689151484388e-08,)
# 1137	(3.346689151484388e-08,)
# 1138	(2.3783648200832862e-08,)
# 1139	(2.3783648200832862e-08,)
# 1140	(2.3783648200832862e-08,)
# 1141	(2.3783648200832862e-08,)
# 1142	(2.3783648200832862e-08,)
# 1143	(2.3783648200832862e-08,)
# 1144	(2.3783648200832862e-08,)
# 1145	(2.3783648200832862e-08,)
# 1146	(2.3783648200832862e-08,)
# 1147	(2.3783648200832862e-08,)
# 1148	(2.3783648200832862e-08,)
# 1149	(2.3783648200832862e-08,)
# 1150	(2.3783648200832862e-08,)
# 1151	(2.3783648200832862e-08,)
# 1152	(2.3783648200832862e-08,)
# 1153	(1.963081133043953e-08,)
# 1154	(1.963081133043953e-08,)
# 1155	(1.963081133043953e-08,)
# 1156	(1.963081133043953e-08,)
# 1157	(1.963081133043953e-08,)
# 1158	(1.963081133043953e-08,)
# 1159	(1.963081133043953e-08,)
# 1160	(1.963081133043953e-08,)
# 1161	(1.963081133043953e-08,)
# 1162	(1.963081133043953e-08,)
# 1163	(1.963081133043953e-08,)
# 1164	(1.963081133043953e-08,)
# 1165	(1.963081133043953e-08,)
# 1166	(1.963081133043953e-08,)
# 1167	(1.963081133043953e-08,)
# 1168	(1.963081133043953e-08,)
# 1169	(1.963081133043953e-08,)
# 1170	(1.963081133043953e-08,)
# 1171	(1.963081133043953e-08,)
# 1172	(1.963081133043953e-08,)
# 1173	(1.963081133043953e-08,)
# 1174	(1.963081133043953e-08,)
# 1175	(1.963081133043953e-08,)
# 1176	(1.963081133043953e-08,)
# 1177	(1.6160135208170345e-08,)
# 1178	(1.6160135208170345e-08,)
# 1179	(1.6160135208170345e-08,)
# 1180	(1.6160135208170345e-08,)
# 1181	(1.6160135208170345e-08,)
# 1182	(1.6160135208170345e-08,)
# 1183	(1.453858398372347e-08,)
# 1184	(1.453858398372347e-08,)
# 1185	(1.453858398372347e-08,)
# 1186	(1.2359181978582345e-08,)
# 1187	(1.2111496724511272e-08,)
# 1188	(1.2111496724511272e-08,)
# 1189	(1.2111496724511272e-08,)
# 1190	(1.2111496724511272e-08,)
# 1191	(1.2111496724511272e-08,)
# 1192	(1.2111496724511272e-08,)
# 1193	(1.2111496724511272e-08,)
# 1194	(1.2111496724511272e-08,)
# 1195	(1.2111496724511272e-08,)
# 1196	(1.2111496724511272e-08,)
# 1197	(1.2111496724511272e-08,)
# 1198	(1.2111496724511272e-08,)
# 1199	(1.2111496724511272e-08,)
# 1200	(1.2111496724511272e-08,)
# 1201	(1.2111496724511272e-08,)
# 1202	(1.2111496724511272e-08,)
# 1203	(1.2111496724511272e-08,)
# 1204	(1.2111496724511272e-08,)
# 1205	(1.2111496724511272e-08,)
# 1206	(1.2111496724511272e-08,)
# 1207	(1.2111496724511272e-08,)
# 1208	(1.2111496724511272e-08,)
# 1209	(1.1436444838659724e-08,)
# 1210	(1.1436444838659724e-08,)
# 1211	(1.1436444838659724e-08,)
# 1212	(1.1436444838659724e-08,)
# 1213	(1.1436444838659724e-08,)
# 1214	(1.0595252359130835e-08,)
# 1215	(1.0595252359130835e-08,)
# 1216	(1.0595252359130835e-08,)
# 1217	(1.0595252359130835e-08,)
# 1218	(1.0595252359130835e-08,)
# 1219	(1.0595252359130835e-08,)
# 1220	(1.0595252359130835e-08,)
# 1221	(1.0595252359130835e-08,)
# 1222	(1.0595252359130835e-08,)
# 1223	(9.812416421460603e-09,)
# 1224	(9.812416421460603e-09,)
# 1225	(9.812416421460603e-09,)
# 1226	(9.812416421460603e-09,)
# 1227	(4.889192983649236e-09,)
# 1228	(4.889192983649236e-09,)
# 1229	(4.889192983649236e-09,)
# 1230	(4.889192983649236e-09,)
# 1231	(4.889192983649236e-09,)
# 1232	(4.889192983649236e-09,)
# 1233	(4.889192983649236e-09,)
# 1234	(4.889192983649236e-09,)
# 1235	(4.889192983649236e-09,)
# 1236	(4.889192983649236e-09,)
# 1237	(4.889192983649236e-09,)
# 1238	(4.889192983649236e-09,)
# 1239	(4.889192983649236e-09,)
# 1240	(4.889192983649236e-09,)
# 1241	(4.889192983649236e-09,)
# 1242	(4.889192983649236e-09,)
# 1243	(4.889192983649236e-09,)
# 1244	(4.889192983649236e-09,)
# 1245	(4.889192983649236e-09,)
# 1246	(4.889192983649236e-09,)
# 1247	(4.889192983649236e-09,)
# 1248	(2.904728294101382e-09,)
# 1249	(2.904728294101382e-09,)
# 1250	(2.6331110403341825e-09,)
# 1251	(2.6331110403341825e-09,)
# 1252	(2.6331110403341825e-09,)
# 1253	(2.6331110403341825e-09,)
# 1254	(2.6331110403341825e-09,)
# 1255	(2.6331110403341825e-09,)
# 1256	(2.6331110403341825e-09,)
# 1257	(2.6331110403341825e-09,)
# 1258	(2.6331110403341825e-09,)
# 1259	(2.6331110403341825e-09,)
# 1260	(2.6331110403341825e-09,)
# 1261	(2.6331110403341825e-09,)
# 1262	(2.6331110403341825e-09,)
# 1263	(2.6331110403341825e-09,)
# 1264	(2.6331110403341825e-09,)
# 1265	(2.6331110403341825e-09,)
# 1266	(2.6331110403341825e-09,)
# 1267	(2.6331110403341825e-09,)
# 1268	(2.6331110403341825e-09,)
# 1269	(2.6331110403341825e-09,)
# 1270	(2.6331110403341825e-09,)
# 1271	(2.6331110403341825e-09,)
# 1272	(2.6331110403341825e-09,)
# 1273	(2.6331110403341825e-09,)
# 1274	(2.6331110403341825e-09,)
# 1275	(2.6331110403341825e-09,)
# 1276	(2.6331110403341825e-09,)
# 1277	(2.6331110403341825e-09,)
# 1278	(2.6331110403341825e-09,)
# 1279	(2.6331110403341825e-09,)
# 1280	(2.6331110403341825e-09,)
# 1281	(2.6331110403341825e-09,)
# 1282	(2.6331110403341825e-09,)
# 1283	(2.6331110403341825e-09,)
# 1284	(2.6331110403341825e-09,)
# 1285	(2.6331110403341825e-09,)
# 1286	(1.7504049512120946e-09,)
# 1287	(1.7504049512120946e-09,)
# 1288	(1.7504049512120946e-09,)
# 1289	(1.7504049512120946e-09,)
# 1290	(1.7504049512120946e-09,)
# 1291	(1.7504049512120946e-09,)
# 1292	(1.7504049512120946e-09,)
# 1293	(1.7504049512120946e-09,)
# 1294	(1.7504049512120946e-09,)
# 1295	(1.741229346137249e-09,)
# 1296	(1.5781865028119114e-09,)
# 1297	(1.5781865028119114e-09,)
# 1298	(1.5781865028119114e-09,)
# 1299	(1.5781865028119114e-09,)
# 1300	(1.5781865028119114e-09,)
# 1301	(1.5781865028119114e-09,)
# 1302	(1.5781865028119114e-09,)
# 1303	(1.5781865028119114e-09,)
# 1304	(1.5781865028119114e-09,)
# 1305	(1.5781865028119114e-09,)
# 1306	(1.5781865028119114e-09,)
# 1307	(1.5781865028119114e-09,)
# 1308	(1.5781865028119114e-09,)
# 1309	(1.5285536538569389e-09,)
# 1310	(1.5285536538569389e-09,)
# 1311	(1.5285536538569389e-09,)
# 1312	(1.5285536538569389e-09,)
# 1313	(1.5285536538569389e-09,)
# 1314	(1.5285536538569389e-09,)
# 1315	(1.5285536538569389e-09,)
# 1316	(1.5285536538569389e-09,)
# 1317	(1.5285536538569389e-09,)
# 1318	(1.5285536538569389e-09,)
# 1319	(1.5285536538569389e-09,)
# 1320	(1.0864534093583558e-09,)
# 1321	(1.0864534093583558e-09,)
# 1322	(1.0864534093583558e-09,)
# 1323	(1.0864534093583558e-09,)
# 1324	(1.0864534093583558e-09,)
# 1325	(1.0864534093583558e-09,)
# 1326	(1.0864534093583558e-09,)
# 1327	(1.0864534093583558e-09,)
# 1328	(1.0864534093583558e-09,)
# 1329	(1.0864534093583558e-09,)
# 1330	(1.0864534093583558e-09,)
# 1331	(1.0864534093583558e-09,)
# 1332	(1.0864534093583558e-09,)
# 1333	(1.0864534093583558e-09,)
# 1334	(1.0864534093583558e-09,)
# 1335	(1.0864534093583558e-09,)
# 1336	(1.0864534093583558e-09,)
# 1337	(1.0864534093583558e-09,)
# 1338	(1.0864534093583558e-09,)
# 1339	(1.0864534093583558e-09,)
# 1340	(1.0864534093583558e-09,)
# 1341	(8.742147351297578e-10,)
# 1342	(8.742147351297578e-10,)
# 1343	(8.742147351297578e-10,)
# 1344	(8.57607381266192e-10,)
# 1345	(8.57607381266192e-10,)
# 1346	(8.57607381266192e-10,)
# 1347	(8.57607381266192e-10,)
# 1348	(5.963395566916805e-10,)
# 1349	(5.963395566916805e-10,)
# 1350	(5.963395566916805e-10,)
# 1351	(5.963395566916805e-10,)
# 1352	(5.963395566916805e-10,)
# 1353	(5.963395566916805e-10,)
# 1354	(5.963395566916805e-10,)
# 1355	(5.963395566916805e-10,)
# 1356	(4.6564507313431607e-10,)
# 1357	(4.6564507313431607e-10,)
# 1358	(4.6564507313431607e-10,)
# 1359	(4.6564507313431607e-10,)
# 1360	(4.6564507313431607e-10,)
# 1361	(4.091618433989377e-10,)
# 1362	(4.091618433989377e-10,)
# 1363	(4.091618433989377e-10,)
# 1364	(4.091618433989377e-10,)
# 1365	(4.091618433989377e-10,)
# 1366	(4.091618433989377e-10,)
# 1367	(4.091618433989377e-10,)
# 1368	(4.091618433989377e-10,)
# 1369	(3.9148138037900255e-10,)
# 1370	(3.9148138037900255e-10,)
# 1371	(3.9148138037900255e-10,)
# 1372	(3.9148138037900255e-10,)
# 1373	(3.9148138037900255e-10,)
# 1374	(3.9148138037900255e-10,)
# 1375	(3.9148138037900255e-10,)
# 1376	(3.9148138037900255e-10,)
# 1377	(3.9148138037900255e-10,)
# 1378	(3.9148138037900255e-10,)
# 1379	(3.9148138037900255e-10,)
# 1380	(3.9148138037900255e-10,)
# 1381	(3.9148138037900255e-10,)
# 1382	(3.9148138037900255e-10,)
# 1383	(3.9148138037900255e-10,)
# 1384	(3.8910789804269785e-10,)
# 1385	(3.8910789804269785e-10,)
# 1386	(3.8910789804269785e-10,)
# 1387	(3.8910789804269785e-10,)
# 1388	(3.8910789804269785e-10,)
# 1389	(3.8910789804269785e-10,)
# 1390	(3.8910789804269785e-10,)
# 1391	(3.8910789804269785e-10,)
# 1392	(3.8910789804269785e-10,)
# 1393	(3.8910789804269785e-10,)
# 1394	(3.8910789804269785e-10,)
# 1395	(3.8910789804269785e-10,)
# 1396	(3.8910789804269785e-10,)
# 1397	(3.8910789804269785e-10,)
# 1398	(3.8910789804269785e-10,)
# 1399	(3.8910789804269785e-10,)
# 1400	(3.8910789804269785e-10,)
# 1401	(3.8910789804269785e-10,)
# 1402	(3.8910789804269785e-10,)
# 1403	(3.8910789804269785e-10,)
# 1404	(3.8910789804269785e-10,)
# 1405	(2.630820186037184e-10,)
# 1406	(2.630820186037184e-10,)
# 1407	(2.630820186037184e-10,)
# 1408	(2.630820186037184e-10,)
# 1409	(2.630820186037184e-10,)
# 1410	(2.630820186037184e-10,)
# 1411	(2.630820186037184e-10,)
# 1412	(2.630820186037184e-10,)
# 1413	(2.630820186037184e-10,)
# 1414	(2.630820186037184e-10,)
# 1415	(1.993769631774039e-10,)
# 1416	(1.993769631774039e-10,)
# 1417	(1.993769631774039e-10,)
# 1418	(1.993769631774039e-10,)
# 1419	(1.6204059137924435e-10,)
# 1420	(1.6204059137924435e-10,)
# 1421	(1.6204059137924435e-10,)
# 1422	(1.6204059137924435e-10,)
# 1423	(1.6204059137924435e-10,)
# 1424	(1.6204059137924435e-10,)
# 1425	(1.4350318224640484e-10,)
# 1426	(1.4350318224640484e-10,)
# 1427	(1.4350318224640484e-10,)
# 1428	(1.4350318224640484e-10,)
# 1429	(1.4350318224640484e-10,)
# 1430	(1.4350318224640484e-10,)
# 1431	(1.4350318224640484e-10,)
# 1432	(1.4350318224640484e-10,)
# 1433	(1.4350318224640484e-10,)
# 1434	(1.4350318224640484e-10,)
# 1435	(1.4350318224640484e-10,)
# 1436	(1.4350318224640484e-10,)
# 1437	(1.4350318224640484e-10,)
# 1438	(1.4350318224640484e-10,)
# 1439	(1.4350318224640484e-10,)
# 1440	(1.4350318224640484e-10,)
# 1441	(1.4350318224640484e-10,)
# 1442	(1.4350318224640484e-10,)
# 1443	(1.4350318224640484e-10,)
# 1444	(6.864433352966512e-11,)
# 1445	(6.864433352966512e-11,)
# 1446	(6.864433352966512e-11,)
# 1447	(6.864433352966512e-11,)
# 1448	(6.864433352966512e-11,)
# 1449	(6.864433352966512e-11,)
# 1450	(6.864433352966512e-11,)
# 1451	(6.864433352966512e-11,)
# 1452	(6.864433352966512e-11,)
# 1453	(6.864433352966512e-11,)
# 1454	(6.864433352966512e-11,)
# 1455	(6.864433352966512e-11,)
# 1456	(6.864433352966512e-11,)
# 1457	(6.864433352966512e-11,)
# 1458	(6.864433352966512e-11,)
# 1459	(6.864433352966512e-11,)
# 1460	(4.8015539471411675e-11,)
# 1461	(4.8015539471411675e-11,)
# 1462	(4.8015539471411675e-11,)
# 1463	(4.8015539471411675e-11,)
# 1464	(4.8015539471411675e-11,)
# 1465	(4.8015539471411675e-11,)
# 1466	(4.763806138859841e-11,)
# 1467	(4.763806138859841e-11,)
# 1468	(4.763806138859841e-11,)
# 1469	(4.763806138859841e-11,)
# 1470	(4.763806138859841e-11,)
# 1471	(4.763806138859841e-11,)
# 1472	(4.763806138859841e-11,)
# 1473	(4.0000357496445004e-11,)
# 1474	(4.0000357496445004e-11,)
# 1475	(4.0000357496445004e-11,)
# 1476	(4.0000357496445004e-11,)
# 1477	(4.0000357496445004e-11,)
# 1478	(4.0000357496445004e-11,)
# 1479	(4.0000357496445004e-11,)
# 1480	(4.0000357496445004e-11,)
# 1481	(4.0000357496445004e-11,)
# 1482	(4.0000357496445004e-11,)
# 1483	(4.0000357496445004e-11,)
# 1484	(4.0000357496445004e-11,)
# 1485	(4.0000357496445004e-11,)
# 1486	(4.0000357496445004e-11,)
# 1487	(4.0000357496445004e-11,)
# 1488	(2.9049178827430376e-11,)
# 1489	(2.9049178827430376e-11,)
# 1490	(2.9049178827430376e-11,)
# 1491	(2.9049178827430376e-11,)
# 1492	(2.9049178827430376e-11,)
# 1493	(2.9049178827430376e-11,)
# 1494	(2.9049178827430376e-11,)
# 1495	(2.9049178827430376e-11,)
# 1496	(2.9049178827430376e-11,)
# 1497	(2.9049178827430376e-11,)
# 1498	(2.9049178827430376e-11,)
# 1499	(2.9049178827430376e-11,)
# array('d', [-3.3397855899568447e-06, 2.783805789667998e-06, 1.1156704227653373e-06, -7.926014230708005e-07, -5.654434392590797e-07, 1.9538749903226727e-06, -6.673741837680213e-07, 2.188175240235281e-07, 1.2261282193258025e-06, 1.462356070474708e-06])

# %% [markdown]
# ### [Bohachevsky benchmark problem](http://deap.readthedocs.org/en/latest/api/benchmarks.html#deap.benchmarks.bohachevsky)
#
# $$\text{minimize } f(\mathbf{x}) = \sum_{i=1}^{N-1}(x_i^2 + 2x_{i+1}^2 - 0.3\cos(3\pi x_i) - 0.4\cos(4\pi x_{i+1}) + 0.7), \mathbf{x}\in \left[-100,100\right]^n,$$
#
# Optimum in $\mathbf{x}=\mathbf{0}$, $f(\mathbf{x})=0$.
#
# <img src='http://deap.readthedocs.org/en/latest/_images/bohachevsky.png' width='50%' align='center'/>
